# %% [markdown]
# ## The Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('DATA/cancer_classification.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# ...

# %% [markdown]
# ## EDA

# %%
sns.countplot(x="benign_0__mal_1", data=df)
# Out:
# <AxesSubplot:xlabel='benign_0__mal_1', ylabel='count'>

# %%
df.corr()['benign_0__mal_1'][:-1].sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Train Test Split

# %%
X = df.drop('benign_0__mal_1', axis = 1).values
y = df['benign_0__mal_1'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=101)

# %% [markdown]
# ## Scaling the Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Creating the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
X_train.shape
# Out:
# (426, 30)

# %%
model = Sequential()

model.add(Dense(30, activation='relu'))

model.add(Dense(15, activation='relu'))
# BINARY CLASSIFICATION
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %% [markdown]
# ## Training the Model

# %%
model.fit(x=X_train, y=y_train, epochs=600,validation_data=(X_test,y_test))
# Out:
# Epoch 1/600
# 14/14 [==============================] - 0s 7ms/step - loss: 0.6869 - val_loss: 0.6547
# Epoch 2/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6383 - val_loss: 0.6016
# Epoch 3/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5903 - val_loss: 0.5540
# Epoch 4/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5410 - val_loss: 0.4989
# Epoch 5/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4833 - val_loss: 0.4399
# Epoch 6/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4285 - val_loss: 0.3848
# Epoch 7/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3755 - val_loss: 0.3362
# Epoch 8/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3313 - val_loss: 0.2987
# Epoch 9/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2947 - val_loss: 0.2648
# Epoch 10/600
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Our training loss is still going down but validation loss is begining to increase. We're overfitting to our training data set

# %% [markdown]
# ### Model with Early Stopping

# %%
model = Sequential()

model.add(Dense(30, activation='relu'))

model.add(Dense(15, activation='relu'))
# BINARY CLASSIFICATION
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
help(EarlyStopping)
# Out:
# Help on class EarlyStopping in module keras.callbacks:
#
# class EarlyStopping(Callback)
#  |  EarlyStopping(monitor='val_loss', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
#  |
#  |  Stop training when a monitored metric has stopped improving.
#  |
#  |  Assuming the goal of a training is to minimize the loss. With this, the
#  |  metric to be monitored would be `'loss'`, and mode would be `'min'`. A
#  |  `model.fit()` training loop will check at end of every epoch whether
#  |  the loss is no longer decreasing, considering the `min_delta` and
#  |  `patience` if applicable. Once it's found no longer decreasing,
#  |  `model.stop_training` is marked True and the training terminates.
#  |
#  |  The quantity to be monitored needs to be available in `logs` dict.
#  |  To make it so, pass the loss or metrics at `model.compile()`.
#  |
#  |  Args:
#  |    monitor: Quantity to be monitored.
# ...

# %%
# Since we want to do monitoring "validation loss", put val_loss on monitor and we want to minimize the "validation loss" so put min on the mode
early_stop = EarlyStopping(monitor='val_loss', mode='min',verbose=1,patience=25)

# %%
model.fit(x=X_train, y=y_train, epochs=600,validation_data=(X_test,y_test),
         callbacks=[early_stop])
# Out:
# Epoch 1/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.6728 - val_loss: 0.6575
# Epoch 2/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6351 - val_loss: 0.6212
# Epoch 3/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5967 - val_loss: 0.5804
# Epoch 4/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5546 - val_loss: 0.5349
# Epoch 5/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5087 - val_loss: 0.4870
# Epoch 6/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4633 - val_loss: 0.4393
# Epoch 7/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4180 - val_loss: 0.3937
# Epoch 8/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3775 - val_loss: 0.3547
# Epoch 9/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3407 - val_loss: 0.3158
# Epoch 10/600
# ...

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Model with DropOut Layers

# %%
from tensorflow.keras.layers import Dropout

# %%
model = Sequential()

model.add(Dense(30, activation='relu'))
# Half of neurons during each batch(one batch is one entire epoch of training) will be turned off randomly 
model.add(Dropout(0.5))

model.add(Dense(15, activation='relu'))
model.add(Dropout(0.5))

# BINARY CLASSIFICATION
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam')

# %%
model.fit(x=X_train, y=y_train, epochs=600,validation_data=(X_test,y_test),
         callbacks=[early_stop])
# Out:
# Epoch 1/600
# 14/14 [==============================] - 0s 6ms/step - loss: 0.7018 - val_loss: 0.6825
# Epoch 2/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6881 - val_loss: 0.6672
# Epoch 3/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6673 - val_loss: 0.6542
# Epoch 4/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6455 - val_loss: 0.6395
# Epoch 5/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6391 - val_loss: 0.6244
# Epoch 6/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6323 - val_loss: 0.6081
# Epoch 7/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6120 - val_loss: 0.5868
# Epoch 8/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6052 - val_loss: 0.5649
# Epoch 9/600
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5800 - val_loss: 0.5428
# Epoch 10/600
# ...

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Evaluation

# %%
predictions = (model.predict(X_test) > 0.5)*1
# Out:
# 5/5 [==============================] - 0s 626us/step

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        55
#            1       0.98      0.98      0.98        88
#
#     accuracy                           0.97       143
#    macro avg       0.97      0.97      0.97       143
# weighted avg       0.97      0.97      0.97       143

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[53  2]
#  [ 2 86]]
